# %%
import requests
import html_to_json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from pyshadow.main import Shadow
from bs4 import BeautifulSoup
import time

# %%
base_url = "https://www.swiggy.com/"
driver = webdriver.Chrome()

driver.get(base_url)
location_element = driver.find_element(by=By.XPATH, value='//*[@id="location"]')
# location = input("enter a city: ")
location = "Bangalore"
location_element.send_keys(location)
location_element.send_keys(Keys.ENTER)
time.sleep(3)
# html = location_element.get_attribute("innerHTML")
# soup = BeautifulSoup(html)
# print(soup.prettify())
driver.find_element(by=By.XPATH,
                    value='//*[@id="root"]/div[1]/div[1]/div/div[1]/div[1]/div/div[2]/div/div[2]/button[1]').click()
time.sleep(5)
# ele = driver.find_elements(by = By.XPATH, value='//*[@id="all_restaurants"]/div/div[2]/div[1]/div/div')
# print(len(ele))

# height = driver.get_window_size()
# height1 = height['height']

max_element_val = driver.find_element(by=By.XPATH,
                                      value='//*[@id="all_restaurants"]/div/div[1]/div/div/div/div[1]').text
max_element_val = int(max_element_val.split()[0])
#print(max_element_val)

j = 0
k = 1000
while True:
    driver.execute_script(f"window.scrollTo({j}, {k});")
    time.sleep(1)
    ele = driver.find_elements(by=By.XPATH, value='//*[@id="all_restaurants"]/div/div[2]/div[1]/div/div')
    print(len(ele))
    if len(ele) >= (max_element_val // 4):
        break
    else:
        j = j + 500
        k = k + 500

#     if element_val<len(ele):
#         element_val = len(ele)
#         height1 = height1*4
    
#     else:
#         break

print("we are here outside the while loop")

elements = driver.find_elements(by=By.XPATH, value='//*[@id="all_restaurants"]/div/div[2]/div[1]/div/div')
print(len(elements))
# Out:
# 4
# 8
# 8
# 8
# 8
# 12
# 12
# 12
# 16
# 16
# 16
# 20
# 20
# 20
# 24
# 24
# 24
# 24
# 28
# 28
# 28
# 28
# 32
# 32
# 36
# 36
# 36
# 40
# 40
# 40
# 40
# 40
# 44
# 44
# 44
# 44
# 44
# 48
# 52
# 52
# 52
# 56
# 56
# 56
# 60
# 60
# 60
# 64
# 64
# 64
# 68
# 68
# 68
# 68
# 72
# 72
# 72
# 72
# 76
# 76
# 80
# 80
# 80
# 84
# 84
# 84
# 84
# 84
# 88
# 88
# 92
# 92
# 92
# 96
# 96
# 96
# 96
# 100
# 100
# 100
# 104
# 104
# 104
# 108
# 108
# 108
# 108
# 112
# 112
# 112
# 116
# 116
# 116
# 120
# 120
# 120
# 124
# 124
# 124
# 124
# 124
# 128
# 128
# 132
# we are here outside the while loop
# 132

# %%
html_list = []

# Loop through the elements and get their innerHTML
for ele in elements:
    html = ele.get_attribute("innerHTML")
    # Append the innerHTML to the list
    html_list.append(html)

print(html_list)
# Out:
# ['<div class="_3XX_A"><a href="/restaurants/maharaja-military-canteen-donne-biryani-dinnur-main-road-r-t-nagar-bangalore-402919" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="Maharaja Military Canteen - Donne Biryani" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/34eca74d4d3c695a0bf85951b2666000"></div><div class="IJsqo" style="background: rgb(58, 60, 65); color: rgb(255, 255, 255); border-color: rgb(30, 32, 35) transparent;"><div class="_1kXWW">Promoted</div></div><div class="_3Ztcd"><div class="nA6kb">Maharaja Military Canteen - Donne Biryani</div><div class="_1gURR" title="Biryani, South Indian, Kebabs">Biryani, South Indian, Kebabs</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.0</span></div><div>•</div><div>36 MINS</div><div>•</div><div class="nVWSi">₹300 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">40% off | Use TRYNEW</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/burger-king-7th-block-koramangala-bangalore-5934" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="Burger King" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/e33e1d3ba7d6b2bb0d45e1001b731fcf"></div><div class="_3Ztcd"><div class="nA6kb">Burger King</div><div class="_1gURR" title="Burgers, American">Burgers, American</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.2</span></div><div>•</div><div>41 MINS</div><div>•</div><div class="nVWSi">₹350 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">60% off | Use STEALDEAL</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/biryani-pot-maruti-nagar-btm-layout-bangalore-428" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="Biryani Pot" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/mdipoyzfzsa7n7igskht"></div><div class="_3Ztcd"><div class="nA6kb">Biryani Pot</div><div class="_1gURR" title="North Indian, Biryani">North Indian, Biryani</div></div><div class="_3Mn31"><div class="_9uwBC _2lAlc"><span class="icon-star _537e4"></span><span>3.9</span></div><div>•</div><div>31 MINS</div><div>•</div><div class="nVWSi">₹500 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">FLAT100 off | Use FLATDEAL</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/rolls-on-wheels-dinnur-main-road-r-t-nagar-bangalore-2998" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="Rolls On Wheels" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/cd378225ea0b386708df030ff9640e62"></div><div class="IJsqo" style="background: rgb(58, 60, 65); color: rgb(255, 255, 255); border-color: rgb(30, 32, 35) transparent;"><div class="_1kXWW">Promoted</div></div><div class="_3Ztcd"><div class="nA6kb">Rolls On Wheels</div><div class="_1gURR" title="Fast Food, North Indian">Fast Food, North Indian</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.1</span></div><div>•</div><div>33 MINS</div><div>•</div><div class="nVWSi">₹300 FOR TWO</div></div><div class="Zl ...

# %%
import re
import pandas as pd

# List to store the restaurant data
restaurant_data = []

# Loop through the html strings and extract the restaurant data
for html in html_list:
#     restaurant_ids = re.findall('data-rest-id="(.*?)"', html)
    restaurant_links = re.findall('<a href="(.*?)">', html)
    name = re.findall('<div class="nA6kb">(.*?)</div>', html)
    rating = re.findall('<span class="icon-star _537e4"></span><span>(.*?)</span>', html)
    cusins = re.findall('<div class="_1gURR" title="(.*?)">', html)
    price = re.findall('<div class="nVWSi">(.*?)</div>', html)
    delivery_time = re.findall('<div>(\d+) MINS</div>', html)
    
    # If price or cusins not found, set it to empty string
    if not price:
        price = [""]
    if not cusins:
        cusins = [""]
        
    # Add the restaurant data to the list
    restaurant_data.append([restaurant_links[0],name[0], rating[0], cusins[0], price[0], delivery_time[0]])
    restaurant_data.append([restaurant_links[1],name[1], rating[1], cusins[1], price[1], delivery_time[1]])
    restaurant_data.append([restaurant_links[2],name[2], rating[2], cusins[2], price[2], delivery_time[2]])
    

# Create a dataframe from the restaurant data
df= pd.DataFrame(restaurant_data, columns=['Link','Restaurant Name', 'Rating', 'Cusins', 'Price for Two', 'Delivery Time'])
df
# Out:
#                                                   Link  \
# 0    /restaurants/maharaja-military-canteen-donne-b...
# 1    /restaurants/burger-king-7th-block-koramangala...
# 2    /restaurants/biryani-pot-maruti-nagar-btm-layo...
# 3    /restaurants/hotel-empire-brigade-road-hotel-e...
# 4    /restaurants/shawarma-on-wheels-shirdi-sai-bab...
# ..                                                 ...
# 391  /restaurants/uptown-patty-subbayanapalya-banas...
# 392  /restaurants/bombay-sandwich-co-5th-block-kora...
# 393  /restaurants/lassi-forever-blr-6th-block-koram...
# 394  /restaurants/maggi-baba-shivajinagar-no-55-coc...
# 395  /restaurants/falafel-house-st-thomas-town-kamm...
#
#                                Restaurant Name Rating  \
# 0    Maharaja Military Canteen - Donne Biryani    4.0
# 1                                  Burger King    4.2
# 2                                  Biryani Pot    3.9
# 3                                 Hotel Empire    4.2
# 4                           Shawarma on Wheels    4.2
# ..                                         ...    ...
# 391                               UPTOWN PATTY     --
# 392                         BOMBAY SANDWICH CO    2.5
# 393                          Lassi forever@BLR     --
# 394                                 MAGGI BABA    3.2
# 395                              FALAFEL HOUSE     --
#
#                                           Cusins Price for Two Delivery Time
# 0                  Biryani, South Indian, Kebabs  ₹300 FOR TWO            36
# 1                              Burgers, American  ₹350 FOR TWO            41
# 2                          North Indian, Biryani  ₹500 FOR TWO            31
# 3                  North Indian, Kebabs, Biryani  ₹450 FOR TWO            28
# 4                     Arabian, Snacks, Fast Food  ₹400 FOR TWO            38
# ..                                           ...           ...           ...
# 391               Fast Food, Desserts, Beverages  ₹299 FOR TWO            45
# 392                                       Snacks  ₹200 FOR TWO            35
# 393                               Sweets, Juices  ₹250 FOR TWO            39
# 394  Beverages, Ice Cream, Continental, Desserts  ₹250 FOR TWO            35
# 395       Indian, Arabian, Healthy Food, Mexican  ₹300 FOR TWO            45
#
# [396 rows x 6 columns]

# %%
df.to_excel("xyz.xlsx", index=False)
